# %% [markdown]
# Use this notebook to just look at the event markers sent to the NIC2 (Enobio) recording software through Lab Streaming Layer (LSL)

# %%
import mne
import numpy as np

# %%
# %matplotlib notebook

# %%
filename = '../data/20181211155701_Patient01_1.edf'

# %%
raw = mne.io.read_raw_edf(filename, preload=True)
# Out:
# Extracting EDF parameters from ../data/20181211155701_Patient01_1.edf...
# EDF file detected
# EDF annotations detected (consider using raw.find_edf_events() to extract them)
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 5999  =      0.000 ...    11.998 secs...

# %%
raw.info
# Out:
# <Info | 17 non-empty fields
#     bads : list | 0 items
#     buffer_size_sec : float | 1.0
#     ch_names : list | P3, Pz, P4, PO7, PO8, Oz, F3, F4, X, ...
#     chs : list | 12 items (EEG: 11, STIM: 1)
#     comps : list | 0 items
#     custom_ref_applied : bool | False
#     dev_head_t : Transform | 3 items
#     events : list | 0 items
#     highpass : float | 0.0 Hz
#     hpi_meas : list | 0 items
#     hpi_results : list | 0 items
#     lowpass : float | 250.0 Hz
#     meas_date : int | 1544543830
#     nchan : int | 12
#     proc_history : list | 0 items
#     projs : list | 0 items
#     sfreq : float | 500.0 Hz
#     acq_pars : NoneType
#     acq_stim : NoneType
#     ctf_head_t : NoneType
#     description : NoneType
#     dev_ctf_t : NoneType
#     dig : NoneType
#     experimenter : NoneType
#     file_id : NoneType
#     gantry_angle : NoneType
#     hpi_subsystem : NoneType
#     kit_system_id : NoneType
#     line_freq : NoneType
#     meas_id : NoneType
# ...

# %%
raw.info['events']
# Out:
# []

# %%
raw.info['ch_names']
# Out:
# ['P3', 'Pz', 'P4', 'PO7', 'PO8', 'Oz', 'F3', 'F4', 'X', 'Y', 'Z', 'STI 014']

# %%
raw.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
data = raw.get_data(picks=None)

# %%
np.shape(data)
# Out:
# (12, 6000)

# %%
np.max(data[-1])
# Out:
# 1.0

# %%
np.unique(data[-1])
# Out:
# array([0., 1.])

# %%
from matplotlib import pyplot as plt

# %%
plt.figure()
plt.plot(data[-1])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.where(data == 1)
# Out:
# (array([11, 11, 11, 11, 11], dtype=int64),
#  array([ 992, 1493, 1993, 2993, 3493], dtype=int64))
